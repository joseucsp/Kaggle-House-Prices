# %% [markdown]
# # House Prices: Advanced Regression Techniques

# %% [markdown]
# ## 1. Getting data with Pandas

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
train_data = pd.read_csv('all/train.csv')
test_data  = pd.read_csv('all/test.csv')

# %%
train_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ## 2. Data exploration

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_data['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## 3. Prepare data

# %%
for var in train_data.columns:
    print('%15s \t %s'%(var, train_data.dtypes[var]))
# Out:
#              Id 	 int64
#      MSSubClass 	 int64
#        MSZoning 	 object
#     LotFrontage 	 float64
#         LotArea 	 int64
#          Street 	 object
#           Alley 	 object
#        LotShape 	 object
#     LandContour 	 object
#       Utilities 	 object
#       LotConfig 	 object
#       LandSlope 	 object
#    Neighborhood 	 object
#      Condition1 	 object
#      Condition2 	 object
#        BldgType 	 object
#      HouseStyle 	 object
#     OverallQual 	 int64
#     OverallCond 	 int64
#       YearBuilt 	 int64
#    YearRemodAdd 	 int64
#       RoofStyle 	 object
#        RoofMatl 	 object
#     Exterior1st 	 object
#     Exterior2nd 	 object
#      MasVnrType 	 object
#      MasVnrArea 	 float64
#       ExterQual 	 object
#       ExterCond 	 object
#      Foundation 	 object
#        BsmtQual 	 object
#        BsmtCond 	 object
#    BsmtExposure 	 object
#    BsmtFinType1 	 object
#      BsmtFinSF1 	 int64
#    BsmtFinType2 	 object
#      BsmtFinSF2 	 int64
# ...

# %%
missing_data = train_data.isnull().sum().sort_values(ascending=True)
missing_data = missing_data[missing_data > 0]

# %%
count        = train_data.isnull().sum().sort_values(ascending=False)
percent_relt = train_data.isnull().sum() / train_data.isnull().count()
percent_relt = percent_relt.sort_values(ascending=False)*100

missing_data_perc  = pd.concat([count, percent_relt], axis=1, keys = ['Count', 'Percent(%)'])
missing_data_perc.head(20)
# Out:
#               Count  Percent(%)
# PoolQC         1453   99.520548
# MiscFeature    1406   96.301370
# Alley          1369   93.767123
# Fence          1179   80.753425
# FireplaceQu     690   47.260274
# LotFrontage     259   17.739726
# GarageCond       81    5.547945
# GarageType       81    5.547945
# GarageYrBlt      81    5.547945
# GarageFinish     81    5.547945
# GarageQual       81    5.547945
# BsmtExposure     38    2.602740
# BsmtFinType2     38    2.602740
# BsmtFinType1     37    2.534247
# BsmtCond         37    2.534247
# BsmtQual         37    2.534247
# MasVnrArea        8    0.547945
# MasVnrType        8    0.547945
# Electrical        1    0.068493
# Utilities         0    0.000000

# %%
train_data = train_data.drop((missing_data_perc[missing_data_perc['Percent(%)'] > 25]).index, 1)

# %%
#train_data['FireplaceQu']  = train_data['FireplaceQu'].fillna('NA')
train_data['LotFrontage']  = train_data['LotFrontage'].fillna(0)
train_data['GarageCond']   = train_data['GarageCond'].fillna('NA')
train_data['GarageType']   = train_data['GarageType'].fillna('NA')
train_data['GarageFinish'] = train_data['GarageFinish'].fillna('NA')
train_data['GarageQual']   = train_data['GarageQual'].fillna('NA')
train_data['BsmtExposure'] = train_data['BsmtExposure'].fillna('NA')
train_data['BsmtFinType2'] = train_data['BsmtFinType2'].fillna('NA')
train_data['BsmtFinType1'] = train_data['BsmtFinType1'].fillna('NA')
train_data['BsmtCond']     = train_data['BsmtCond'].fillna('NA')
train_data['BsmtQual']     = train_data['BsmtQual'].fillna('NA')
train_data['MasVnrArea']   = train_data['MasVnrArea'].fillna(0)
train_data['MasVnrType']   = train_data['MasVnrType'].fillna('None')
train_data['Electrical']   = train_data['Electrical'].fillna('SBrkr')

# %%
train_data['GarageYrBlt'].describe()
train_data['GarageYrBlt']  = train_data['GarageYrBlt'].fillna(1978)

# %%
print('MiscVal  == 0 percent -> %3.2f%%'%(100*(train_data['MiscVal'].values == 0).sum() / train_data['MiscVal'].values.shape[0] ))
print('PoolArea == 0 percent -> %3.2f%%'%(100*(train_data['PoolArea'].values == 0).sum() / train_data['PoolArea'].values.shape[0] ))
# Out:
# MiscVal  == 0 percent -> 96.44%
# PoolArea == 0 percent -> 99.52%

# %%
train_data = train_data.drop('MiscVal', 1)
train_data = train_data.drop('PoolArea', 1)

# %%
numerical_data    = [var for var in train_data.columns if train_data.dtypes[var] != 'object']
categorical_data  = [var for var in train_data.columns if train_data.dtypes[var] == 'object']

numerical_data.remove('Id')
numerical_data.remove('SalePrice')
print('Number of numerical data   : ', len(numerical_data))
print('Number of categorical data : ', len(categorical_data))
# Out:
# Number of numerical data   :  34
# Number of categorical data :  38

# %%
encoders = []
for i, name in enumerate(categorical_data):
    x = train_data[name].values
    encoders.append(LabelEncoder())
    train_data[name] = encoders[i].fit_transform(x)

#scalers  = []
#for i, name in enumerate(numerical_data):
#    x = train_data[name].values
#    x = x.reshape(-1,1)
#    scaler = StandardScaler()
#    scaler.fit(x)
#   scalers.append(scaler)
#    train_data[name] = scalers[i].transform(x)

# %% [markdown]
# ## 4. Model

# %%
def getPrediction(W, b, input_data):
    return np.sum(W*input_data) + b

def RMSE(Y, pred, m):
    return np.sqrt(np.mean(np.square(np.log(Y+1)-np.log(pred+1))))

def train(input_, err, lr):
    global W, b
    W = W  + lr * err * input_
    b = b  + lr * err

# %% [markdown]
# ## 5. Training

# %%
train_data_values = train_data.values

# %%
train_input = train_data_values[:, 1: -1]
train_label = train_data_values[:,-1]

train_input = train_input.astype(np.float32)

# %%
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression

n, m = train_input.shape
X, y = make_regression(n_features=m, random_state=0.0)

# %%
n, m = train_input.shape
W = np.random.normal(0.0, 0.01, m)
b = 0.0
def linear_regression(train_input, train_label):
    global W, b
    n, m    = train_input.shape
    pred_ar = np.ndarray(shape=(n,), dtype=np.float32)
    for i in range(1, 10001):
        for id in range(n):
            pred = getPrediction(W, b, train_input[id])
            err  = train_label[id] - pred
            train(train_input[id], err, 1e-11)
        pred_ar = np.matmul(train_input,W) + b
        pred_ar[pred_ar < 0] = 0
        loss = RMSE(train_label, pred_ar, m)
        if (i%50 == 0):
            print("ep : %5d loss = %.6f"%(i, loss))

linear_regression(train_input, train_label)
# Out:
# ep :    50 loss = 0.301552
# ep :   100 loss = 0.271677
# ep :   150 loss = 0.251211
# ep :   200 loss = 0.237713
# ep :   250 loss = 0.229093
# ep :   300 loss = 0.223746
# ep :   350 loss = 0.220508
# ep :   400 loss = 0.218585
# ep :   450 loss = 0.217455
# ep :   500 loss = 0.216787
# ep :   550 loss = 0.216377
# ep :   600 loss = 0.216103
# ep :   650 loss = 0.215895
# ep :   700 loss = 0.215714
# ep :   750 loss = 0.215540
# ep :   800 loss = 0.215364
# ep :   850 loss = 0.215183
# ep :   900 loss = 0.214999
# ep :   950 loss = 0.214812
# ep :  1000 loss = 0.214625
# ep :  1050 loss = 0.214440
# ep :  1100 loss = 0.214258
# ep :  1150 loss = 0.214082
# ep :  1200 loss = 0.213913
# ep :  1250 loss = 0.213751
# ep :  1300 loss = 0.213597
# ep :  1350 loss = 0.213451
# ep :  1400 loss = 0.213313
# ep :  1450 loss = 0.213183
# ep :  1500 loss = 0.213062
# ep :  1550 loss = 0.212949
# ep :  1600 loss = 0.212843
# ep :  1650 loss = 0.212745
# ep :  1700 loss = 0.212654
# ...

# %% [markdown]
# ## 6. Testing

# %%
test_data = test_data.drop((missing_data_perc[missing_data_perc['Percent(%)'] > 25]).index, 1)

# %%
#test_data['FireplaceQu']  = test_data['FireplaceQu'].fillna('NA')
test_data['LotFrontage']  = test_data['LotFrontage'].fillna(0)
test_data['GarageCond']   = test_data['GarageCond'].fillna('NA')
test_data['GarageType']   = test_data['GarageType'].fillna('NA')
test_data['GarageFinish'] = test_data['GarageFinish'].fillna('NA')
test_data['GarageQual']   = test_data['GarageQual'].fillna('NA')
test_data['BsmtExposure'] = test_data['BsmtExposure'].fillna('NA')
test_data['BsmtFinType2'] = test_data['BsmtFinType2'].fillna('NA')
test_data['BsmtFinType1'] = test_data['BsmtFinType1'].fillna('NA')
test_data['BsmtCond']     = test_data['BsmtCond'].fillna('NA')
test_data['BsmtQual']     = test_data['BsmtQual'].fillna('NA')
test_data['MasVnrArea']   = test_data['MasVnrArea'].fillna(0)
test_data['MasVnrType']   = test_data['MasVnrType'].fillna('None')
test_data['Electrical']   = test_data['Electrical'].fillna('SBrkr')

# %%
test_data['GarageYrBlt']  = test_data['GarageYrBlt'].fillna(1978)

# %%
test_data.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# MSZoning        4
# BsmtFullBath    2
# Utilities       2
# BsmtHalfBath    2
# Functional      2
# TotalBsmtSF     1
# GarageArea      1
# BsmtFinSF2      1
# BsmtUnfSF       1
# SaleType        1
# Exterior2nd     1
# Exterior1st     1
# KitchenQual     1
# GarageCars      1
# BsmtFinSF1      1
# Condition1      0
# LotShape        0
# BsmtCond        0
# MSSubClass      0
# LotFrontage     0
# dtype: int64

# %%
test_data['MSZoning']     = test_data['MSZoning'].fillna('RM')
test_data['Functional']   = test_data['Functional'].fillna('Typ')
test_data['BsmtFullBath'] = test_data['BsmtFullBath'].fillna(0)
test_data['BsmtHalfBath'] = test_data['BsmtFullBath'].fillna(0)
test_data['Utilities']    = test_data['Utilities'].fillna('AllPub')
test_data['GarageArea']   = test_data['GarageArea'].fillna(0)
test_data['BsmtFinSF2']   = test_data['BsmtFinSF2'].fillna(0)
test_data['BsmtUnfSF']    = test_data['BsmtUnfSF'].fillna(0)
test_data['SaleType']     = test_data['SaleType'].fillna('Oth')
test_data['Exterior2nd']  = test_data['Exterior2nd'].fillna('Other')
test_data['Exterior1st']  = test_data['Exterior1st'].fillna('Other')
test_data['KitchenQual']  = test_data['KitchenQual'].fillna('TA')
test_data['GarageCars']   = test_data['GarageCars'].fillna(0)
test_data['TotalBsmtSF']  = test_data['TotalBsmtSF'].fillna(0)
test_data['BsmtFinSF1']   = test_data['BsmtFinSF1'].fillna(0)

# %%
test_data = test_data.drop('MiscVal', 1)
test_data = test_data.drop('PoolArea', 1)

# %%
test_data['Id'].describe()
# Out:
# count    1459.000000
# mean     2190.000000
# std       421.321334
# min      1461.000000
# 25%      1825.500000
# 50%      2190.000000
# 75%      2554.500000
# max      2919.000000
# Name: Id, dtype: float64

# %%
for i,name in enumerate(categorical_data):
    x = test_data[name].values
    test_data[name] = encoders[i].fit_transform(x)
test_data_values = test_data.values
test_data.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0  1461          20         2         80.0    11622       1         3
# 1  1462          20         3         81.0    14267       1         0
# 2  1463          60         3         74.0    13830       1         0
# 3  1464          60         3         78.0     9978       1         0
# 4  1465         120         3         43.0     5005       1         0
#
#    LandContour  Utilities  LotConfig      ...        PavedDrive  WoodDeckSF  \
# 0            3          0          4      ...                 2         140
# 1            3          0          0      ...                 2         393
# 2            3          0          4      ...                 2         212
# 3            3          0          4      ...                 2         360
# 4            1          0          4      ...                 2           0
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  MoSold  YrSold  \
# ...

# %%
test_input       = test_data_values[:, 1:]
test_input       = test_input.astype(np.float32)

# %%
n, m         = test_input.shape
pred_test_ar = np.matmul(test_input,W) + b

# %%
pred_pd = pd.DataFrame(pred_test_ar, columns=['SalePrice'])
out     = pd.concat([test_data['Id'],pred_pd], axis=1)

out.to_csv('all/my_submission.csv',index=False)

# %%
tt1 = pd.read_csv('all/my_submission.csv')
tt1
# Out:
#         Id      SalePrice
# 0     1461  152786.345654
# 1     1462  181622.602992
# 2     1463  188702.100469
# 3     1464  192159.942690
# 4     1465  165928.814510
# 5     1466  171160.008928
# 6     1467  177232.179588
# 7     1468  148342.096488
# 8     1469  180687.084589
# 9     1470  142436.695436
# 10    1471  190934.257477
# 11    1472  130816.005726
# 12    1473  132235.458116
# 13    1474  164033.939926
# 14    1475   98855.172368
# 15    1476  276632.027182
# 16    1477  230013.090135
# 17    1478  261393.883119
# 18    1479  241917.568362
# 19    1480  424424.469406
# 20    1481  288409.595791
# 21    1482  181178.486277
# 22    1483  159469.796332
# 23    1484  148485.201830
# 24    1485  132810.791280
# 25    1486  177472.231123
# 26    1487  301425.046810
# 27    1488  240801.503647
# 28    1489  172560.326208
# 29    1490  203264.735112
# ...    ...            ...
# 1429  2890   82348.441809
# 1430  2891  177553.077759
# 1431  2892   30703.019488
# ...

# %%
# Out:
# 0
